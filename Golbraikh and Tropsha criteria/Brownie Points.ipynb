# %% [markdown]
# # Brownie Points :)

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import csv
import random
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolDescriptors
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.metrics import accuracy_score

# %%
df_train=pd.read_csv("C:\\Users\\HP\\Desktop\\Epidemio\\QSAR Modelling\\Training_Dataset_csv.csv")
df_test=pd.read_csv("C:\\Users\\HP\\Desktop\\Epidemio\\QSAR Modelling\\Test_Dataset_csv.csv")

# %%
df_train
# Out:
#                                                SMILES  pIC50 (IC50 in microM)  \
# 0    CC1=NC(SCC(=O)NC2=CC=C(Cl)C=C2F)=NC(=C1)C(F)(F)F               -2.698970
# 1   COC1=CC=C(C=C1)C1=NC(SCC(=O)NC2=CC=C(C=C2)C(C)...               -2.602060
# 2   CC(C)(C)C1=CC=C(NC(=O)CSC2=NC(C3CCCCC3)=C(C#N)...               -2.544068
# 3   CCOC1=CC=C(C=C1)N1C(=O)CC(SC2=NC(C)=CC(C)=N2)C1=O               -2.477121
# 4   CCOC(=O)C1=CN=C(SCC(=O)NC2=CC=C(C=C2)[N+]([O-]...               -2.397940
# ..                                                ...                     ...
# 79  CC1=C(Cl)C=C(Cl)C(=C1)S(=O)(=O)C1=C(C=C(C=C1[N...                0.522879
# 80  [O-][N+](=O)C1=C(C=CC=C1)C1=CC=C(O1)C(=O)OC1=C...                0.681937
# 81                   ClC1=CC(OC(=O)C2=CC=NC=C2)=CN=C1                0.785156
# 82        ClC1=CC(OC(=O)C2=CC3=C(OC2=O)C=CC=C3)=CN=C1                0.966576
# 83    ClC1=CC=C(C=C1)C1=CC=C(O1)C(=O)OC1=CN=CC(Cl)=C1                1.200659
#
#        logP  MolecularWeight  RotatableBonds  AromaticProportion    TPSA  \
# 0   4.32712       379.016924               4            0.785714   54.88
# 1   5.00640       393.151098               7            0.772727   64.11
# 2   4.71758       424.193297               5            0.521739   98.64
# 3   2.91634       357.114712               5            0.666667   72.39
# 4   1.87450       377.079390               7            0.800000  150.34
# ..      ...              ...             ...                 ...     ...
# 79  4.96982       457.935397               4            0.857143  120.42
# 80  4.12240       344.019999               4            1.000000   95.47
# 81  2.34920       234.019605               2            1.000000   52.08
# 82  3.06060       301.014185               2            1.000000   69.40
# 83  4.86760       332.995948               3            1.000000   52.33
#
#     RingCount  HBA  HBD
# 0           2    4    1
# 1           3    5    1
# 2           3    5    2
# 3           3    6    0
# 4           2    9    2
# ..        ...  ...  ...
# 79          2    6    0
# 80          3    6    0
# 81          2    4    0
# 82          3    5    0
# 83          3    4    0
#
# [84 rows x 10 columns]

# %%
df_test
# Out:
#                                               SMILES  pIC50 (IC50 in microM)  \
# 0           ClC1=CC(OC(=O)C2=C3C=CC=CC3=CC=C2)=CN=C1                0.604802
# 1  CC1=CC(O)=NC(SCC(=O)NC2=CC=C(OC3=CC=C(Cl)C=C3)...               -1.800866
# 2  CC1=C(C=C(O1)C(C)(C)C)C1=NNC(NS(=O)(=O)C2=CC=C...               -1.584018
# 3  ClC(Cl)=C(Cl)C(=O)OC1=CC=C(C=C1)S(=O)(=O)C1=CC...               -0.009410
# 4  O=C1N(CC2=CC=C3C=CC=CC3=C2)C2=CC=C(C=C2C1=O)S(...               -0.664983
# 5  IC1=CC=C2N(C\C=C\C3=CC4=CC=CC=C4S3)C(=O)C(=O)C...               -0.405841
# 6         CC1CCCCN1S(=O)(=O)C1=CC2=C(NC(=O)C2=O)C=C1               -0.565664
# 7  [O-][N+](=O)C1=CC=C(C=C1)C1=CC=C(O1)C(=O)OC1=C...                0.304126
# 8  CC(SC1=NC(C2=CC=CC=C2)=C(C#N)C(=O)N1)C(=O)NC1=...               -1.966286
# 9   CC(C)C1=CC=C(NC(=O)CSC2=NC(=CC=N2)C2=CC=CS2)C=C1               -2.001400
#
#       logP  MolecularWeight  RotatableBonds  AromaticProportion   TPSA  \
# 0  4.10740       283.040006               2            1.000000  39.19
# 1  4.66712       401.060090               6            0.894737  84.34
# 2  4.13792       365.086784               4            0.687500  87.99
# 3  6.10120       561.817275               6            1.000000  86.74
# 4  3.74390       434.130028               4            0.750000  74.76
# 5  4.74860       444.963348               3            0.947368  37.38
# 6  1.38450       308.083078               2            0.571429  83.55
# 7  4.12240       344.019999               4            1.000000  95.47
# 8  4.08128       410.060424               5            0.900000  98.64
# 9  5.05930       369.096954               6            0.789474  54.88
#
#    RingCount  HBA  HBD
# 0          3    3    0
# 1          3    6    2
# 2          3    5    2
# 3          2    6    0
# 4          5    4    0
# 5          4    3    0
# 6          3    4    1
# 7          3    6    0
# 8          3    5    2
# 9          3    5    1

# %%
#Merging Data
combined_df = pd.concat([df_train, df_test], axis=0)
combined_df.to_csv('merged_file.csv', index=False)

# %%
combined_df
# Out:
#                                                SMILES  pIC50 (IC50 in microM)  \
# 0    CC1=NC(SCC(=O)NC2=CC=C(Cl)C=C2F)=NC(=C1)C(F)(F)F               -2.698970
# 1   COC1=CC=C(C=C1)C1=NC(SCC(=O)NC2=CC=C(C=C2)C(C)...               -2.602060
# 2   CC(C)(C)C1=CC=C(NC(=O)CSC2=NC(C3CCCCC3)=C(C#N)...               -2.544068
# 3   CCOC1=CC=C(C=C1)N1C(=O)CC(SC2=NC(C)=CC(C)=N2)C1=O               -2.477121
# 4   CCOC(=O)C1=CN=C(SCC(=O)NC2=CC=C(C=C2)[N+]([O-]...               -2.397940
# ..                                                ...                     ...
# 5   IC1=CC=C2N(C\C=C\C3=CC4=CC=CC=C4S3)C(=O)C(=O)C...               -0.405841
# 6          CC1CCCCN1S(=O)(=O)C1=CC2=C(NC(=O)C2=O)C=C1               -0.565664
# 7   [O-][N+](=O)C1=CC=C(C=C1)C1=CC=C(O1)C(=O)OC1=C...                0.304126
# 8   CC(SC1=NC(C2=CC=CC=C2)=C(C#N)C(=O)N1)C(=O)NC1=...               -1.966286
# 9    CC(C)C1=CC=C(NC(=O)CSC2=NC(=CC=N2)C2=CC=CS2)C=C1               -2.001400
#
#        logP  MolecularWeight  RotatableBonds  AromaticProportion    TPSA  \
# 0   4.32712       379.016924               4            0.785714   54.88
# 1   5.00640       393.151098               7            0.772727   64.11
# 2   4.71758       424.193297               5            0.521739   98.64
# 3   2.91634       357.114712               5            0.666667   72.39
# 4   1.87450       377.079390               7            0.800000  150.34
# ..      ...              ...             ...                 ...     ...
# 5   4.74860       444.963348               3            0.947368   37.38
# 6   1.38450       308.083078               2            0.571429   83.55
# 7   4.12240       344.019999               4            1.000000   95.47
# 8   4.08128       410.060424               5            0.900000   98.64
# 9   5.05930       369.096954               6            0.789474   54.88
#
#     RingCount  HBA  HBD
# 0           2    4    1
# 1           3    5    1
# 2           3    5    2
# 3           3    6    0
# 4           2    9    2
# ..        ...  ...  ...
# 5           4    3    0
# 6           3    4    1
# 7           3    6    0
# 8           3    5    2
# 9           3    5    1
#
# [94 rows x 10 columns]

# %%
# Load the original CSV file
df = pd.read_csv('merged_file.csv')

# Shuffle the rows of the dataframe
df = df.sample(frac=1)

# Split the dataframe into two new dataframes
split_index = int(df.shape[0] * 0.8) # 80% split
df1, df2 = df.iloc[:split_index], df.iloc[split_index:]

# Save the two new dataframes as CSV files
df1.to_csv('train_file.csv', index=False)
df2.to_csv('test_file.csv', index=False)

# %% [markdown]
# # Internal Validation

# %%
train_data=pd.read_csv("train_file.csv")
test_data=pd.read_csv("test_file.csv")

# %%
X_train = train_data[["logP", "MolecularWeight", "RotatableBonds", "AromaticProportion", "TPSA", "RingCount", "HBA", "HBD"]]
y_train = train_data["pIC50 (IC50 in microM)"]
X_test= test_data[["logP", "MolecularWeight", "RotatableBonds", "AromaticProportion", "TPSA", "RingCount", "HBA", "HBD"]]
y_test = test_data["pIC50 (IC50 in microM)"]

# %%
#Random Forest for Validation
rf = RandomForestRegressor(n_estimators=90)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
#Performance Checking using validation dataset"
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Error            : ", mae)
print("Mean Squared Error             : ", mse)
print("R-squared scorer               :", r2)
print("Root mean squared Error        : ", rmse)
print("Mean absolute percentage error : ", mape)
# Out:
# Mean Absolute Error            :  0.5472823226616349
# Mean Squared Error             :  0.5118820066914898
# R-squared scorer               : 0.1824881224805487
# Root mean squared Error        :  0.7154592977182488
# Mean absolute percentage error :  0.5591025204615317

# %%
from sklearn.model_selection import LeaveOneOut, cross_val_score
from sklearn.metrics import make_scorer

# define the LOO-CV method
loo = LeaveOneOut()

# define the scoring metric, in this case R^2 
scoring = make_scorer(r2_score)

# calculate the LOO-CV score
loo_q2_score = cross_val_score(rf, X_train, y_train, cv=loo, scoring=scoring)
print(loo_q2_score)
# Out:
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\HP\anaconda3\envs\KunalBiogen\lib\site-packages\sklearn\metrics\_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan]
